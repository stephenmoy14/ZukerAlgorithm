# %%
import numpy as np
import re

# Turner Rule Parameter File
with open("rna_turner2004.par") as file1:
  file_content = file1.read()
file1.close()
# Split the file content into sections
hairpin = file_content[file_content.find('# hairpin'):file_content.find('# hairpin_enthalpies')].split('\n',1)[1]
mismatch_interior = file_content[file_content.find('# mismatch_interior'):file_content.find('# mismatch_interior_enthalpies')].split('\n',1)[1]
bulge = file_content[file_content.find('# bulge'):file_content.find('# bulge_enthalpies')].split('\n',1)[1]
stack = file_content[file_content.find('# stack'):file_content.find('# stack_enthalpies')].split('\n',1)[1]
interior = file_content[file_content.find('# interior'):file_content.find('# interior_enthalpies')].split('\n',1)[1]
mismatch_hairpin = file_content[file_content.find('# mismatch_hairpin'):file_content.find('# mismatch_hairpin_enthalpies')].split('\n',1)[1]


def parse_data(data, pattern, has_header=False, header_length=0):
    energies = {}
    if has_header:
      base_pair_1 = data.split('\n')[0].split()[1:header_length+1]

    # Extract values for every pattern match
    for match in re.finditer(pattern, data):
        # Get header_length number of energy_values
        energy_values = tuple(map(int, match.groups()[:header_length]))
        if has_header: # next group has second base pair
          base_pair_2 = match.group(header_length+1)
        else:
          base_pair_1 = match.group(6)
          base_pair_2 = match.group(7)

        if has_header: # header has first base pair
          for i in range(header_length):
            energies[(base_pair_1[i], base_pair_2)] = energy_values[i]
        else:
          for i,v in enumerate(['E','A','C','G','U']):
            energies[(base_pair_1, base_pair_2+v)] = energy_values[i]

    return energies

stack_values = parse_data(stack, r'\s+(-?\d+)\s+(-?\d+)\s+(-?\d+)\s+(-?\d+)\s+(-?\d+)\s+(-?\d+)\s+(-?\d+)\s+/\*\s+([AUGCNS]+)\s*\*/', has_header=True, header_length=7)
mismatch_hairpin_values = parse_data(mismatch_hairpin, r'\s+(-?\d+)\s+(-?\d+)\s+(-?\d+)\s+(-?\d+)\s+(-?\d+)\s+/\*\s+([AUGCNS]+),([AUGCE])\s*\*/', has_header=False, header_length=5)
mismatch_interior_values = parse_data(mismatch_interior, r'\s+(-?\d+)\s+(-?\d+)\s+(-?\d+)\s+(-?\d+)\s+(-?\d+)\s+/\*\s+([AUGCNS]+),([AUGCE])\s*\*/', has_header=False, header_length=5)

hairpin_values = {}
for i, value in enumerate(hairpin.split()):
  hairpin_values[i] = int(value) if value != 'INF' else np.inf

bulge_values = {}
for i, value in enumerate(bulge.split()):
  bulge_values[i] = int(value) if value != 'INF' else np.inf

interior_values = {}
for i, value in enumerate(interior.split()):
  interior_values[i] = int(value) if value != 'INF' else np.inf

# %%
def FH(i, j, sequence):
    # i,j are indices of base pairs closing the loop

    loop_size = j - i - 1  # Number of unpaired bases

    if loop_size < 3:
        return float('inf')

    # Base pair closing the loop
    bp_closing = (sequence[i], sequence[j])

    # Loop size penalty
    loop_penalty = hairpin_values.get(loop_size, hairpin_values[max(hairpin_values.keys())])

    # Mismatch penalty
    if loop_size >= 4:
        mismatch_values = (bp_closing, sequence[i + 1] + sequence[j-1])
        mismatch_penalty = mismatch_hairpin_values.get(mismatch_values, 0)
    else:
        mismatch_penalty = 0

    return loop_penalty + mismatch_penalty

def FL(i, j, h, k, sequence):
    # i,j are outer base pair indices
    # h,k are inner base pair indices

    outer_bp = sequence[i] + sequence[j]
    inner_bp = sequence[h] + sequence[k]
    loop_size_1 = h - i - 1  # Unpaired bases on the left side
    loop_size_2 = j - k - 1  # Unpaired bases on the right side

    # Stack region (no unpaired bases)
    if loop_size_1 == 0 and loop_size_2 == 0:
        return 'S', stack_values.get((outer_bp, inner_bp), float('inf'))

    # Bulge loop (unpaired bases on one side)
    if loop_size_1 == 0 or loop_size_2 == 0:
        bulge_size = max(loop_size_1, loop_size_2)
        bulge_penalty = bulge_values.get(bulge_size, bulge_values[max(bulge_values.keys())])
        return 'B', bulge_penalty

    # Interior loop (unpaired bases on both sides)
    if loop_size_1 > 0 and loop_size_2 > 0:
        interior_size = loop_size_1 + loop_size_2
        interior_penalty = interior_values.get(interior_size, interior_values[max(interior_values.keys())])

        # Add mismatch penalties
        mismatch_penalty_1 = mismatch_interior_values.get((outer_bp, sequence[i + 1] + sequence[j-1]), 0)
        mismatch_penalty_2 = mismatch_interior_values.get((inner_bp, sequence[h - 1] + sequence[k+1]), 0)
        return 'I', interior_penalty + mismatch_penalty_1 + mismatch_penalty_2
    return 'N', float('inf')

# %%
def is_paired(i, j, sequence):
    pairs = {'A': 'U', 'U': 'A', 'G': 'C', 'C': 'G'}
    return pairs.get(sequence[i]) == sequence[j]

def compute_dp(sequence, MIN_LOOP_SIZE=4):
    n = len(sequence)

    # Initialize matrices
    V = np.full((n, n), float('inf')) # loops matrix
    W = np.full((n, n), float('inf')) # overall matrix
    P = np.full((n, n), -2) # note pairs/partitions
    l = np.full((n, n, 2), -1) # bounds for partitions


    for j in range(n):
      for i in range(n-1,-1,-1):
        if i >= j:
          continue
        if j - i + 1 < MIN_LOOP_SIZE:
          continue
        # Compute V[i, j]
        if is_paired(i, j, sequence):
          # hairpin (1st case)
          V[i, j] = FH(i, j, sequence)
          l[i, j, 0] = i + 1
          l[i, j, 1] = j - 1
          for h in range(i + 1, j):
            for k in range(h + 1, j):
              # 2nd order loop (2nd case)
                loop_type, second_order_energy = FL(i, j, h, k, sequence)

                if second_order_energy + V[h, k] < V[i, j] and (j - i + 1) >= MIN_LOOP_SIZE:
                  V[i, j] = second_order_energy + V[h, k]
                  if loop_type == 'S':
                    # Stack
                    l[i, j, 0] = i+1
                    l[i, j, 1] = j-1
                  elif loop_type == 'B' or loop_type == 'I':
                    # Bulge or Interior
                    l[i, j, 0] = h
                    l[i, j, 1] = k

          for k in range(i + 1, j):
            # bifurcation loop (3rd case)
            if W[i,k] + W[k+1,j] < V[i,j]:
              V[i,j] = W[i,k] + W[k+1,j]
              l[i,j,0] = k
              l[i,j,1] = k

        # Compute W[i, j]
        # use loop matrix (3rd case)
        W[i,j] = min(V[i,j], W[i,j])
        if is_paired(i, j, sequence):
          P[i, j] = -1
        else:
          P[i,j] = -2
        if i + 1 < n:
          # skip left (1st case)
          W[i, j] = min(W[i, j], W[i + 1, j])
        if j - 1 >= 0:
          # skip right (2nd case)
          W[i, j] = min(W[i, j], W[i,j-1])
        for k in range(i+1, j):
          # partition (4th case)
          if W[i,k] + W[k+1,j] < W[i,j]:
            W[i,j] = W[i,k] + W[k+1,j]
            P[i,j] = k

    return V, W, P, l

def traceback(i, j, sequence, P, l, MIN_LOOP_SIZE=4):
    structure = ['.'] * len(sequence)
    stack = [(i, j)]

    while stack:
      x, y = stack.pop()
      if x >= y:
        continue
      if y - x + 1 < MIN_LOOP_SIZE:
        continue
      k = P[x, y]  # Split point for current subsequence

      if k == -1:  # Hairpin or base-pair
        structure[x] = '('
        structure[y] = ')'
        ip = l[x, y, 0]  # Left boundary
        jp = l[x, y, 1]  # Right boundary
        if ip != jp:
          # Base pair between x,y
          stack.append((ip, jp))
        else:
          # Bifurcation: Split into parts
          stack.append((x + 1, ip))
          stack.append((ip + 1, y - 1))
      elif k >= 0:
        # Split sequence at k
        stack.append((x, k))
        stack.append((k + 1, y))
      elif x + 1 < y and W[x, y] == W[x + 1, y]:
        # Skip left
        stack.append((x + 1, y))
      elif x < y - 1 and W[x, y] == W[x, y - 1]:
        # Skip right
        stack.append((x, y - 1))

    return ''.join(structure)

# %%
with open('rnafold.small.rna_turner1999.par.mfe.gold', 'r') as testfile:
  data = testfile.read()
testfile.close()
data = data.split('\n')
for i in range(int(len(data)/2)):
  sequence = data[i*2]
  [result, mfe] = data[i*2+1].split(' ')
  mfe = float(mfe[1:len(mfe)-1])
  print(sequence)
  print('Original')
  print(result)
  print(mfe)
  V, W, P, l = compute_dp(sequence)
  mfe2 = W[0,len(sequence)-1]/100
  print('New')
  print(traceback(0, len(sequence)-1, sequence, P, l))
  print(mfe2)
  print('Diff')
  print(mfe-mfe2)
# Out:
# AGACGACAAGGUUGAAUCGCACCCACAGUCUAUGAGUCGGUGACAACAUUACGAAAGGCUGUAAAAUCAAUUAUUCACCACAGGGGGCCCCCGUGUCUAG
# Original
# ((((.((..(((.((((.......(((((((.(((((.(....).)).)))....)))))))..........)))))))...(((....)))))))))..
# -24.03
# New
# ((((.(....((((.....((((......((...))..)))).))))..)(((.....((((..(((.(..))))....))))(((..))))))))))..
# -21.2
# Diff
# -2.830000000000002
# CCACUCAUUAAGUCCAAAGCUACGAGCGACAUUUCGAUGGGUGCGUCGACUGCGCUUACAGCGGCGGGGUGUAGACGACCUGUGUGAUAAUCUUUAAUAU
# Original
# .(((..............(((..(((((.((..((((((....)))))).)))))))..))).(((((.((....)).))))))))..............
# -26.4
# New
# .(((.((....(((....(((...)))))).....(.......((((.((..((((...)))).......)).))))..))).)))..............
# -24.4
# Diff
# -2.0
# UUAGGCAGUCGCCGCUCGUUCGCGUGUAUGCUCCUUUGUCAGUCAGCCUACUAUAGCACUGCUCCAACUGGAUUCGGCAGCGUUCGCAUAGCGUCCUUGC
# Original
# ...(((....)))((..(..((((((((((((((...(.((((..((........)))))))(((....)))...)).)))))..)))).)))..)..))
# -25.9
# New
# %%
from sklearn.metrics import f1_score, precision_score, recall_score

def calculate_metrics(predicted_structure, reference_structure):
    tp = sum(1 for i in range(len(predicted_structure)) if predicted_structure[i] == '(' and reference_structure[i] == '(')
    fp = sum(1 for i in range(len(predicted_structure)) if predicted_structure[i] == '(' and reference_structure[i] != '(')
    fn = sum(1 for i in range(len(reference_structure)) if reference_structure[i] == '(' and predicted_structure[i] != '(')

    precision = tp / (tp + fp) if tp + fp > 0 else 0
    sensitivity = tp / (tp + fn) if tp + fn > 0 else 0
    f1 = 2 * (precision * sensitivity) / (precision + sensitivity) if precision + sensitivity > 0 else 0

    return precision, sensitivity, f1
total_mfe_diff = 0
total_normalize_mfe_diff = 0
total_precision = 0
total_sensitivity = 0
total_f1 = 0

# Loop over each sequence
for i in range(int(len(data)/2)):
    sequence = data[i*2]
    reference_structure, mfe = data[i*2+1].split(' ')
    mfe = float(mfe[1:-1])

    V, W, P, l = compute_dp(sequence)
    predicted_structure = traceback(0, len(sequence)-1, sequence, P, l)
    predicted_mfe = W[0, len(sequence)-1] / 100

    precision, sensitivity, f1 = calculate_metrics(predicted_structure, reference_structure)
    total_mfe_diff += mfe - predicted_mfe
    total_normalize_mfe_diff += (mfe - predicted_mfe) / len(sequence)

    # Accumulate the metrics
    total_precision += precision
    total_sensitivity += sensitivity
    total_f1 += f1

    # Print results for each sequence
    print(f"Sequence: {sequence}")
    print(f"Original Structure: {reference_structure}")
    print(f"Predicted Structure: {predicted_structure}")
    print(f"Original MFE: {mfe}")
    print(f"Predicted MFE: {predicted_mfe}")
    print(f"Difference in MFE: {mfe - predicted_mfe}")
    print(f"Normalized Difference in MFE: {(mfe - predicted_mfe) / len(sequence)}")
    print(f"Precision: {precision:.3f}, Sensitivity: {sensitivity:.3f}, F1-Score: {f1:.3f}")

# Calculate and print the averages of the metrics
num_sequences = len(data) // 2
average_precision = total_precision / num_sequences
average_sensitivity = total_sensitivity / num_sequences
average_f1 = total_f1 / num_sequences

print(f"Average Precision: {average_precision:.3f}")
print(f"Average Sensitivity: {average_sensitivity:.3f}")
print(f"Average F1-Score: {average_f1:.3f}")
print(f"Average Difference in MFE: {total_mfe_diff / num_sequences}")
print(f"Average Normalized Difference in MFE: {total_normalize_mfe_diff / num_sequences}")
# Out:
# Sequence: AGACGACAAGGUUGAAUCGCACCCACAGUCUAUGAGUCGGUGACAACAUUACGAAAGGCUGUAAAAUCAAUUAUUCACCACAGGGGGCCCCCGUGUCUAG
# Original Structure: ((((.((..(((.((((.......(((((((.(((((.(....).)).)))....)))))))..........)))))))...(((....)))))))))..
# Predicted Structure: ((((.(....((((.....((((......((...))..)))).))))..)(((.....((((..(((.(..))))....))))(((..))))))))))..
# Original MFE: -24.03
# Predicted MFE: -21.2
# Difference in MFE: -2.830000000000002
# Normalized Difference in MFE: -0.02830000000000002
# Precision: 0.414, Sensitivity: 0.414, F1-Score: 0.414
# Sequence: AACCGAUGCAAUCCUUAUCAGAGGGGGGGAGAUUUCGGUCGGCUAUGAUCCUGGCCGUUAACCAUAAGGUCGCCCCAGAGUCGAGCAAAUCUACGCUACG
# Original Structure: ...((((.(..(((((....)))))((((.(((((.(((((((((......))))))...)))...))))).)))).).))))(((........)))...
# Predicted Structure: ..((((.....((..........((((.((..((..(((((((....(...).))))...)))..))..)).)))).)).)))(((.(...)..)))..)
# Original MFE: -31.6
# Predicted MFE: -24.6
# Difference in MFE: -7.0
# Normalized Difference in MFE: -0.07
# Precision: 0.769, Sensitivity: 0.645, F1-Score: 0.702
# Sequence: AUAUAGAUAGUUCCCGCAGCGAUGUCGCGUCCUCAUCCCUAAGGAGGGAAUUCCGGAAUGCCCCACCGCGCGCUGAGAAACAUGCCGGAGUUAGAAGAUA
# Original Structure: .......((..(((.((((((....))).......(((((....))))).((((((..(((......)))..))).)))...))).)))..)).......
# Predicted Structure: .(((......((((..(((((....((((((((..(....)))))(((.((((..)))).))...)))))))))).).(((.(.(..))))).))).)))
# Original MFE: -26.0
# Predicted MFE: -24.9
# Difference in MFE: -1.1000000000000014
# Normalized Difference in MFE: -0.011000000000000015
# Precision: 0.364, Sensitivity: 0.480, F1-Score: 0.414
# Sequence: AGUUGACUGUAAGAGUGGGACACAUGUUCCGGCUAUAGACUUCCUGACAUUGGGACGCGGCCGUGGUGCGUCGAAAGUCAGUACAUGUCUAAUUUUCUCA
# Original Structure: ............(((((((((....))))))....(((((...(((((.((..((((((.(....)))))))..))))))).....))))).....))).
# Predicted Structure: ..(.((....(......(((.((..)))))...)((((((...(((((.((..(((((..(...)..))))).)).))))).....)))))...)))..)
# Original MFE: -30.0
# Predicted MFE: -26.1
# Difference in MFE: -3.8999999999999986
# Normalized Difference in MFE: -0.038999999999999986
# Precision: 0.750, Sensitivity: 0.750, F1-Score: 0.750
# Sequence: UAUUUGCCGCGACAGACUGCUAGGUAGGAGGAGGGAGAUUAACCGAAAAUCUCAAAUUCACUCUCGGGUAUUGGAAUCUCCUCCUGCCCCGGCGUCAAGU
# Original Structure: .....((((((......)))..((((((((((((((((((.......))))))......(((....))).......))))))))))))..))).......
# Predicted Structure: .(.(((.(((............((.(((((((((..((((.......)))).)(..(((.(.(..))......))))))))))))...)).))).))).)
# Original MFE: -36.3
# Predicted MFE: -28.6
# Difference in MFE: -7.699999999999996
# Normalized Difference in MFE: -0.07699999999999996
# Precision: 0.714, Sensitivity: 0.741, F1-Score: 0.727
# Sequence: CCACUGCUCCUUCGUACACUACAUAUAGUUGGGUUCUGGAUGUCAAAGUCGUCAGUCCUCUAGAAGUGUGGUUGAAAGGCCCGAUCGGGGAUUGGUACGC
# Original Structure: (((...((((.(((.(((((.....(((..(((..(((.(((.......)))))).))))))..)))))((((....)))))))..))))..))).....
# Predicted Structure: .....((.((.(((.(((((.....(((..((...(((((...(...)))..))).)).)))..)))))((.(...)..))))).........))...))
# Original MFE: -24.4
# Predicted MFE: -17.4
# Difference in MFE: -7.0
# Normalized Difference in MFE: -0.07
# Precision: 0.885, Sensitivity: 0.742, F1-Score: 0.807
# Sequence: GUCGUGCAUUUAGUCAGAUCCCCAACGCGGCGCAUUCUUCAACAACACUGCUUGUUCGGCGAUAUGACUUGGAAGUCGUACUCAACCCGCUUUGGAAAAA
# Original Structure: (((..((.....))..)))..((((.(((((((......(((((....)).)))....))).(((((((....)))))))......)))).)))).....
# Predicted Structure: .(..((.(.....)))..(..((((.(((((((.......((((((...).)))))..)))....(((((..))))..(.....)))))).))))...))
# Original MFE: -21.5
# Predicted MFE: -20.0
# Difference in MFE: -1.5
# Normalized Difference in MFE: -0.015
# Precision: 0.750, Sensitivity: 0.750, F1-Score: 0.750
# Sequence: GUCAGACUGCCAAGCAACCGACUUUGGGAUAACUCUGUGUUAUUCUGAUAUGGGUGAUAGAGGGGUCGAGCUUCAGUUCGACCAACAUUAAUUGAAAAGG
# Original Structure: .((((....((.....(((.(..(..(((((((.....)))))))..)..).)))......))((((((((....))))))))........)))).....
# Predicted Structure: .(((((.(((...)))(((.(...).)).((((.....))))))))).(....((........(((((((...)...)))))).))..........))..
# Original MFE: -30.6
# Predicted MFE: -18.6
# Difference in MFE: -12.0
# Normalized Difference in MFE: -0.12
# Precision: 0.769, Sensitivity: 0.769, F1-Score: 0.769
# Sequence: CAGAAGCCUCAACUACGCCGAUCGGGAAGAAUCCCCACGUUGCCAAUCCUGUUGAUAGAGCAGCGUUCCAGCCCUCGUAUCUGUAGCGCUUACACUGUGU
# Original Structure: (((((((((((..((((......((((....)))).((((((((.(((.....))).).))))))).........))))..)).)).))))...)))...
# Predicted Structure: ((.((((.....((((..(((..((((....)))).(((.(((.....((......)).))).)).).......))).....)))).))))......)).
# Original MFE: -24.3
# Predicted MFE: -21.7
# Difference in MFE: -2.6000000000000014
# Normalized Difference in MFE: -0.026000000000000013
# Precision: 0.760, Sensitivity: 0.633, F1-Score: 0.691
# Sequence: CCGUCUGCUUUAAUUAGAUGGCCAGAAGAUAACGCCGUCAUGCAAGCAGGUAGUGCAAAGCGUCCCAGAGGGCGGUCCGUCGAUCCGUGACGACCUAUUU
# Original Structure: (..(((((((......((((((...........))))))....)))))))..)........((((....))))((((.((((.....)))))))).....
# Predicted Structure: .((((.(((((.....((.(((..((...)..)))).))..(((..(.....))))))))).....(..((.((......))..)).)))))........
# Original MFE: -28.6
# Predicted MFE: -21.3
# Difference in MFE: -7.300000000000001
# Normalized Difference in MFE: -0.07300000000000001
# Precision: 0.480, Sensitivity: 0.462, F1-Score: 0.471
# Sequence: UUCUUCGACGUUCGUCAACGCAGUCACCACCAAUAUUCUAGCACUUUAGUUGGAACCGUUUCUAGCAUGUAUACGGGCCCUUAAUAGAUUUGGAAAGGGG
# Original Structure: ......(((...((....))..))).((.((....(((((((......)))))))(((..((((((.((....)).))......))))..)))...))))
# Predicted Structure: ..(..((...(.....).))(........((((...((((...........((..((((...((.(..))).)))).)).....)))).)))).....))
# Original MFE: -20.5
# Predicted MFE: -16.9
# Difference in MFE: -3.6000000000000014
# Normalized Difference in MFE: -0.03600000000000001
# Precision: 0.591, Sensitivity: 0.481, F1-Score: 0.531
# Sequence: AAUACUUCACCUUACUCUCUUACACGCAGCAACGCAUGCUUCGUUAAUUUAUGACUAAGAAGACCGCUGGUGCGCCUGUCUUCAUAUGUAGUAGAGUCAC
# Original Structure: .............(((((.(((((((.((((.....)))).)))..............(((((((((....)))...))))))....)))).)))))...
# Predicted Structure: .............(((((...((....((((.....))))..)).(.......((...(((((((((....)))...))))))....))..))))))...
# Original MFE: -24.7
# Predicted MFE: -24.8
# Difference in MFE: 0.10000000000000142
# Normalized Difference in MFE: 0.0010000000000000141
# Precision: 0.870, Sensitivity: 0.800, F1-Score: 0.833
# Sequence: AACAAACCGUCUAUCGUUAGCUCGCCGCCCGCUAGACUUGAGGUCGUAAGGCACCCUGCACUGAUCAGUUUGCAGAUGAUAAUCGGAAUCCGAUAGUUUG
# Original Structure: ..(((((.(((((.((...((.....)).)).))))).....(((((...(((..(((.......)))..)))..))))).(((((...))))).)))))
# Predicted Structure: (((((((.(((((.((...((.....)).)).)))))(..((........(((...))).))....)))))).(.......(((((...)))))..))).
# Original MFE: -24.0
# Predicted MFE: -23.3
# Difference in MFE: -0.6999999999999993
# Normalized Difference in MFE: -0.006999999999999993
# Precision: 0.786, Sensitivity: 0.733, F1-Score: 0.759
# Sequence: AAAGGUCUGGUGUCCCAGGGUUGAGCGUUUCCUGUCGUUGGCGUAUGCGCAAGUAAUCGGUAUCUCUCCUAUGCGAUUCCUUGCCGUAGAAAAUGACCCU
# Original Structure: ..((((((((....)))))..............((((((..(.((((.(((((.(((((.(((.......)))))))).))))))))))..)))))))))
# Predicted Structure: (..(((((((....)))......(...((((....((..(.(....))(((((.(((((.((.......))..))))).)))))))..)))).))))).)
# Original MFE: -26.8
# Predicted MFE: -24.7
# Difference in MFE: -2.1000000000000014
# Normalized Difference in MFE: -0.021000000000000015
# Precision: 0.759, Sensitivity: 0.688, F1-Score: 0.721
# Sequence: AAACACGGAUGGCAUUGUAUCACACUAGCGCUGCAAGAUAAUCUUAAAAUCGGGCAUCUCUAGAUGGACAAUGGGAAUCCACAUGGUGAACUUUCAAAAG
# Original Structure: ......((((..((((((....((((((.(.(((..(((.........)))..))).).)))).)).))))))...))))....................
# Predicted Structure: ...(.(((((..((((((..((..((((.(.(((..(((..(.(..)))))..))).).)))).)).))))))...))))((...)))...(((..))))
# Original MFE: -22.2
# Predicted MFE: -21.4
# Difference in MFE: -0.8000000000000007
# Normalized Difference in MFE: -0.008000000000000007
# Precision: 0.656, Sensitivity: 0.913, F1-Score: 0.764
# Sequence: CUGUUACCCACCCGUACUAUUCAUAUCAAGACGGCACGUUGCACUCAAUUUGCUUCAUUUACACAGACUUGAUCACUUGUACCCAGGCCCUUUCUGUCAU
# Original Structure: .............((((.......((((((..((((.((((....)))).))))((.........)))))))).....)))).((((.....))))....
# Predicted Structure: (.(.......((.((((.......(((((((((...)))((((...(..))))..(.((...).))))))))).....))))...))......).)....
# Original MFE: -12.7
# Predicted MFE: -12.3
# Difference in MFE: -0.3999999999999986
# Normalized Difference in MFE: -0.003999999999999986
# Precision: 0.560, Sensitivity: 0.583, F1-Score: 0.571
# Sequence: GAAGUAUCAUCCUCGGUACUAAACCACAGCCGAAUAACCAGCCUCUCCUGAACAUCGCGAGAGGAACUAGUUGGGUUUUAGGUUAAUUUCGCUUUGUUCC
# Original Structure: ..((((((......))))))....((.(((.((((((((..((((((.((.....)).))))))((((.....))))...)))).)))).))).))....
# Predicted Structure: (..(..........(.(...)..))(....((((.((((..((((((..((...))..)))))).........))))..........))))......).)
# Original MFE: -25.9
# Predicted MFE: -20.0
# Difference in MFE: -5.899999999999999
# Normalized Difference in MFE: -0.05899999999999998
# Precision: 0.762, Sensitivity: 0.516, F1-Score: 0.615
# Sequence: AGCGUGAUUCUCUAUAAGCGUUCUCGCUAGUAAAGCCAUUCAGCUUGAUCCUUAAGAGACUAUUAGUUCAACUGAUAUGCUAGCGGCUACAUCGCGAGUC
# Original Structure: ..((((((...........((..(((((((((((((......))))..............((((((.....)))))))))))))))..))))))))....
# Predicted Structure: .(.(.((...))......)...(((((..((..((((..((((..(((.(.(....))(((...)))))).)))).........))))))...))))).)
# Original MFE: -24.3
# Predicted MFE: -19.7
# Difference in MFE: -4.600000000000001
# Normalized Difference in MFE: -0.04600000000000001
# Precision: 0.481, Sensitivity: 0.481, F1-Score: 0.481
# Sequence: GUCUAGAACCCCCCCGACCCAAAGAUCGAGUUAAAAUUUAUACUCGCACACAGUAGUAUCUAUAAAUACUAUCCCAUCUUGAAAAGCUUAUCGGGCCGAU
# Original Structure: ..............((.(((.((((((((((..........)))))......(((((((......)))))))...)))))((........))))).))..
# Predicted Structure: ....(.......(((((....((((((((((.((...))..)))))......(((((((.(...)))))))...))))))..........)))))....)
# Original MFE: -16.5
# Predicted MFE: -19.1
# Difference in MFE: 2.6000000000000014
# Normalized Difference in MFE: 0.026000000000000013
# Precision: 0.731, Sensitivity: 0.792, F1-Score: 0.760
# Sequence: GAACUUCGUAGCUAGCUCUAGUGCCGCGAUGGGAUCGUCUAAUAGAGAUACGAGGGAGUUUGCUCCAACACGUGGCCCGAUUACUCCGUACUCACAUCAC
# Original Structure: ....((((((.....(((((.....(((((...)))))....))))).))))))((((....)))).....((((..((.......))..).))).....
# Predicted Structure: (...(.((((.....(((((..(...((((...)))).)...))))).))))).((.((...(.(((.(..))))...)...))..)((....))..).)
# Original MFE: -23.6
# Predicted MFE: -23.0
# Difference in MFE: -0.6000000000000014
# Normalized Difference in MFE: -0.006000000000000014
# Precision: 0.630, Sensitivity: 0.654, F1-Score: 0.642
# Sequence: AUCUCAGAUUGCCGAACUGUGCUUUAGCUGGGAUCGAUAACCAUUCAAGAAAAGAUUUAAUGUCACCACAAGGUCUGACCACCCGCCGAAUUCUUGAAGA
# Original Structure: (((((((...((........)).....))))))).........((((((((..(((.....))).......((.....))..........))))))))..
# Predicted Structure: .(((....(...(((.(...(((..))).)...)))......)(.((((((....((..).((....))).((...(......).))...))))))))))
# Original MFE: -18.7
# Predicted MFE: -18.6
# Difference in MFE: -0.09999999999999787
# Normalized Difference in MFE: -0.0009999999999999788
# Precision: 0.520, Sensitivity: 0.591, F1-Score: 0.553
# Sequence: UCCGGGCUUUGUCCAUCUCCGAAAGUCUCAGGAUUUGCCCUGACCCCAUACAGGCCGAGGGGUGGGAUCCUACCUAGACGACCUUGAGAUCAUGAAUUCA
# Original Structure: ...((((...((((.....(....).....))))..))))(((.(.((...(((.((..((((((....))))))...)).))))).).)))........
# Predicted Structure: (..((.(...).))(((((.....((((((((......)))).....(....((...(((..(...).))).)))))))......))))........).)
# Original MFE: -28.8
# Predicted MFE: -21.6
# Difference in MFE: -7.199999999999999
# Normalized Difference in MFE: -0.072
# Precision: 0.333, Sensitivity: 0.308, F1-Score: 0.320
# Sequence: UCCCAUGAGUGAGAACGCACGAUACUCCCACGCGGGUGGCCCCGAGGUGUAAGAUAUCGACGGUGUCCACGGGUUCCUCCUGGGCCGGGCUCGCCCGCAC
# Original Structure: .((((.(((.(((..((..(((((((..(((.((((....))))..)))..)).)))))..((...)).))..)))))).)))).((((....))))...
# Predicted Structure: .(((..(((.(.((.((..((((.((..(((.((((....))))..)))..))..)))).))...))..)(....))))...))..((((..)))))...
# Original MFE: -37.8
# Predicted MFE: -32.3
# Difference in MFE: -5.5
# Normalized Difference in MFE: -0.055
# Precision: 0.897, Sensitivity: 0.812, F1-Score: 0.852
# Sequence: CUUACAGAGUUGGCCUUAAUAUAAGCCCGUGUUGAGGCAUUGAUCGCUACAGUCCGAGUGCCUCGCGGGCAGAACAUCGUAAUAUGGGUAGGUAACCUCG
# Original Structure: ......(((...((((...((((.((((((...(((((((...(((........)))))))))))))))).(.....)....))))...))))...))).
# Predicted Structure: (((((...(((.((((((...))).(.......((((((....(((..(...).))).))))))..))))..)))...))))...(...(((...)))))
# Original MFE: -32.4
# Predicted MFE: -27.3
# Difference in MFE: -5.099999999999998
# Normalized Difference in MFE: -0.050999999999999976
# Precision: 0.517, Sensitivity: 0.536, F1-Score: 0.526
# Sequence: AAGCCCGCCUCGUCCCUAAAAUUUCAUGGGAUAUGCGCGCCUAAAACCUUCAUUGCGACAUAAAUGACGAGCGGACACUUUAUGAAGGUAUUCUCGAAAC
# Original Structure: ..(.((((.(((((((((........)))).((((((((..............)))).))))...))))))))).)..(((..(((....)))..)))..
# Predicted Structure: ((..((((..((((((...(.(...)).))(((((..(((..((.(...)..))))).))))..))))).)))).....)...(((....))))......
# Original MFE: -22.44
# Predicted MFE: -21.2
# Difference in MFE: -1.240000000000002
# Normalized Difference in MFE: -0.01240000000000002
# Precision: 0.679, Sensitivity: 0.679, F1-Score: 0.679
# Sequence: GGGCCUGGUACAAGAUUCAAUCUAACGCACGCGGCCCUCCCCCACCGGUAUAGUUGAAUCGGGCGGUAGCAAGAUUUUAUGAACACGCCGCCGGCGGCGU
# Original Structure: (((((((((...((((...))))...)).)).)))))..........((.((...(((((..((....))..)))))..)).))((((((....))))))
# Predicted Structure: ((......((((..((((...((((((((.((((.(((.....)))..))))....)))))((..(...).))..))).))))..........)))).))
# Original MFE: -23.2
# Predicted MFE: -19.9
# Difference in MFE: -3.3000000000000007
# Normalized Difference in MFE: -0.03300000000000001
# Precision: 0.571, Sensitivity: 0.533, F1-Score: 0.552
# Sequence: UAGCUAAUGCUAGUUGUUCGCUGCACAUGAGGGGGGUUGUUGGGUGGUUCUCCGGGAGGAAGCUGAUUGGGAAUCAGUUUGGGUCUCCCACGGCGGUGCC
# Original Structure: ((((....))))......((((((......((((..(..(...)..)..))))((((((((((((((.....))))))))...))))))...))))))..
# Predicted Structure: ((((....))))(.....(((...(((..(......))))...((((.....)((...((..((((((...))))))......)).))))).)))...).
# Original MFE: -36.9
# Predicted MFE: -22.3
# Difference in MFE: -14.599999999999998
# Normalized Difference in MFE: -0.146
# Precision: 0.615, Sensitivity: 0.533, F1-Score: 0.571
# Sequence: GAACCGACGGAGUACACGCUCUGGACUCCAUAGGCGGAGUAAUCAAGAGGCGGUAAAAGGUCGAUUUUGCUAUCUUUGCGUUCACAAUAACUGUCAUAUC
# Original Structure: (((((((((((((....)))))).(((((......)))))..)).((((..(((((((......)))))))..))))).)))).................
# Predicted Structure: ((.(.(((....(((...((((..(((((......))))).....))))...)))....)))).(..((....(...).....(((.....))))).)))
# Original MFE: -26.7
# Predicted MFE: -20.3
# Difference in MFE: -6.399999999999999
# Normalized Difference in MFE: -0.06399999999999999
# Precision: 0.480, Sensitivity: 0.414, F1-Score: 0.444
# Sequence: UCCCUUAAGUUUAGCACGGAACUGGCCCCAGUUAGCACGAUCAUGGCUACCUGGAUUGCGCAUCUGGCUCCUUCUGAACUCCGUAAAACAGCAUCUUUGC
# Original Structure: ........((((...(((((...((..((((...((.(((((..((...))..))))).))..))))..))........))))).)))).(((....)))
# Predicted Structure: ........((((...(((((.(.((..((((...(((..(((..((...))..))))))....))))..))....)...))))).))).(..(...)).)
# Original MFE: -22.7
# Predicted MFE: -23.1
# Difference in MFE: 0.40000000000000213
# Normalized Difference in MFE: 0.004000000000000021
# Precision: 0.885, Sensitivity: 0.852, F1-Score: 0.868
# Sequence: AUCGCUCUGUCGUGAGGGAUAGAACCGCUUGCCAGAUUCUCAGUUAAGUAGUUUGACUCAGGCAAUACUCCCAUGGCUGUUUUAACCAGCGUGAAUACAC
# Original Structure: .((((.....((((.((..((.....(((((.((((((((......)).))))))...)))))..))..))))))((((.......))))))))......
# Predicted Structure: ..(.......((.(..(((.((((...((....)).))))..((........(((.(...).))).)))))).(((...(...).))).)).).......
# Original MFE: -23.2
# Predicted MFE: -20.1
# Difference in MFE: -3.099999999999998
# Normalized Difference in MFE: -0.03099999999999998
# Precision: 0.391, Sensitivity: 0.310, F1-Score: 0.346
# Sequence: UCGUAGUACUCUGUAGCGCCGGCGCCUGGCAACUGUAUUUUAGACUUGUACUCGUCACCCCAGUGUCGAGACGGAUUUGUGCCGGGGAUUGUCCCCCCUU
# Original Structure: .....(((((((((.(((((((...)))))..(((.....)))....)).((((.(((....))).)))))))))...)))).((((.....))))....
# Predicted Structure: .((...(((...))).))..((.(....(((((.((.(...).))..)).((((.(((....))).))).(......))))))(((.(...))))))...
# Original MFE: -30.3
# Predicted MFE: -24.3
# Difference in MFE: -6.0
# Normalized Difference in MFE: -0.06
# Precision: 0.607, Sensitivity: 0.567, F1-Score: 0.586
# Sequence: AGCCACAUCAACGGUCCGUAGCACUAAGACUACAGAUAGGCCCAGACCGAUAAGAGGGCGGUCGGUUAACCGCUAAACUGGUAAUGCAGUUGGUUAAUAU
# Original Structure: ((((.......((((((((((........)))).(((..((((............)))).)))))...))))...(((((......))))))))).....
# Predicted Structure: ((((...((..(((((.((((...(...)))))...........)))))....))..).(((......)))))..(((((......)))).......).)
# Original MFE: -25.3
# Predicted MFE: -22.8
# Difference in MFE: -2.5
# Normalized Difference in MFE: -0.025
# Precision: 0.750, Sensitivity: 0.692, F1-Score: 0.720
# Sequence: UUGACCAGGGGACCAACACCAGGCCAGCGCCAACAUAAGCCAGGCGGCUGCGUAUUUACAACUUGCAAGUUCCCGCAGGGCGAGUUAAAGGGUGACUGGU
# Original Structure: ...((((((....)..((((.(((....))).......(((..((((..(((((.........)))..))..))))..))).........)))).)))))
# Predicted Structure: ...(((((........((((.(((....)))(((....(((..((((.(((((.(....)))..))).....))))..)))..)))....)))).)))))
# Original MFE: -31.3
# Predicted MFE: -30.1
# Difference in MFE: -1.1999999999999993
# Normalized Difference in MFE: -0.011999999999999993
# Precision: 0.821, Sensitivity: 0.920, F1-Score: 0.868
# Sequence: AUUGGGUCCUAUUGUGCGGAAGCGCAGACUCAAUUCUUACCGAACCCGAUGAGUACCAUGCGCGCACCGCGGUCGCUGUGAGGUAUAUAGCGUCAGACUG
# Original Structure: ((((((((....(((((....))))))))))))).............((((.(((((.((((((.((....))))).))).)))))....))))......
# Predicted Structure: .....(((.....(..(((..(((((.(((((........((....)).)))))....)))))...)))).(.((((...(..(..)))))).).)))..
# Original MFE: -32.9
# Predicted MFE: -29.2
# Difference in MFE: -3.6999999999999993
# Normalized Difference in MFE: -0.03699999999999999
# Precision: 0.192, Sensitivity: 0.167, F1-Score: 0.179
# Sequence: CGCAUAGUAUCGGAACAAAAAAUAUGAAUUUACUAUGGCCCGGCCAUGUAGACCCCCUCUCCUUGAAGUACUGAUACUUUCGGGCGUAAGACUUGAACAG
# Original Structure: .....((((((((.((............(((((.(((((...)))))))))).....((.....)).)).))))))))(((((((....).))))))...
# Predicted Structure: (.(..(((..(((((.((....(....)))).(..((((...)))).))(((.....))).)...(((((....)))).)....))....))).)....)
# Original MFE: -23.9
# Predicted MFE: -20.0
# Difference in MFE: -3.8999999999999986
# Normalized Difference in MFE: -0.038999999999999986
# Precision: 0.462, Sensitivity: 0.414, F1-Score: 0.436
# Sequence: GCUCUGUGUAUUGCGUGGCACCCAAGAGUGCUACAAAGUAGAGGCUUGUGUACCUAACCCGUGAACUUCGUGUGCAAGAACACCGUUUACCCUACGGAAG
# Original Structure: ..((((((...((((((((((......))))))).((((....))))..)))........((((((...((((......)))).))))))..))))))..
# Predicted Structure: .((.(((...((((((((...)))......).(((((((..(((.(.....)))).........))))..)))))))..)))((((..(...))))).))
# Original MFE: -26.0
# Predicted MFE: -20.7
# Difference in MFE: -5.300000000000001
# Normalized Difference in MFE: -0.053000000000000005
# Precision: 0.517, Sensitivity: 0.500, F1-Score: 0.508
# Sequence: CAGACUCCCUUGUAACCCCUUGCUACUCUUUCGCCGAGGGCUACCCGGCAAACUUGGCUCGGAAGCUUAUCGAAAAAACGAAAAUAAGCGUCUUUAGCCA
# Original Structure: ..((.......((((....)))).......))((((.((....)))))).....(((((.(((.((((((((......)))...))))).)))..)))))
# Predicted Structure: .....(...(((.(...(...).)...(.........(((...))).))))....((((..((.((((((((......)))...))))).))...)))))
# Original MFE: -25.44
# Predicted MFE: -21.3
# Difference in MFE: -4.140000000000001
# Normalized Difference in MFE: -0.041400000000000006
# Precision: 0.750, Sensitivity: 0.643, F1-Score: 0.692
# Sequence: GUACGUUCUAUCAGUCAGCUCUUGUCAAGUGACGCUUCACUCGCUAGAAACCCAAACCUACAACGUGCGAAUGACAUUACAUUCUCGUCGCACAACAGCC
# Original Structure: .....(((((.((((.(((....(((....))))))..))).).)))))...............((((((..((........))...)))))).......
# Predicted Structure: (...(..((...)).).(((.((((.(.((((....)))))....((..........)))))).((((((..((.((...))))...)))))...)))))
# Original MFE: -18.3
# Predicted MFE: -20.7
# Difference in MFE: 2.3999999999999986
# Normalized Difference in MFE: 0.023999999999999987
# Precision: 0.500, Sensitivity: 0.609, F1-Score: 0.549
# Sequence: CCUCGCACCUUUUGCGCCAGACACAUCAUACCGAACUUUAAAUUCCGAAGUGCAGCUCCAUCGAGGAAAGGCGGGCUGGUAUUGAUCGGGAUCAAUCCGC
# Original Structure: (((((......((((((..((....))...(.(((.......))).)..))))))......)))))....((((..((((.((....)).))))..))))
# Predicted Structure: ....((.((......(((.((....))...(....((((......(((..((..(..))))))...))))..)))).)).(((((((..)))))))..))
# Original MFE: -21.1
# Predicted MFE: -22.8
# Difference in MFE: 1.6999999999999993
# Normalized Difference in MFE: 0.016999999999999994
# Precision: 0.296, Sensitivity: 0.296, F1-Score: 0.296
# Sequence: CUCCGCCCAGCUCUUAGCUACGUGACUAUGUCGCAGUCUGAUUCUAUGGUUCACGCCCUCUCGAACAGGGGCACCACACCCACUUUAUUUCCUGAGGGUC
# Original Structure: .........((((((((....((((((((((((.....))))...)))).))))(((((........)))))...................)))))))).
# Predicted Structure: ..((((..((((...))))(...((((..(...)))))............)...))(........((((((........))(.......))))).)))..
# Original MFE: -24.2
# Predicted MFE: -20.5
# Difference in MFE: -3.6999999999999993
# Normalized Difference in MFE: -0.03699999999999999
# Precision: 0.409, Sensitivity: 0.360, F1-Score: 0.383
# Average Precision: 0.594
# Average Sensitivity: 0.567
# Average F1-Score: 0.578
# Average Difference in MFE: -3.5394
# Average Normalized Difference in MFE: -0.035393999999999995
